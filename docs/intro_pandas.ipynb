# %% [markdown]
# # Introdução ao Pandas
#
# Agora vamos colocar a mão na massa!
#
# Ao final dessa aula vamos conseguir:
#
# 0. Entender o jupyter notebook, instalar e chamar bibliotecas;
# 1. Realizar operações matemáticas básicas;
# 2. Importar um arquivo .csv;
# 3. Manipular o arquivo dataframe e chegar a conclusões;
# 4. Unir dois dataframes distintos a partir de uma base comum.
#
# Algumas orientações:
#
# A partir de agora, as anotações deverão ser apenas no seu script, utilizando os # para fazer comentários:

# %%
#Isso é um comentário

# %% [markdown]
# Pelo menos nesta aula, não se preocupem em escrever o código: copiem as célular deste script e procurem entender o que cada função faz. Isso é essencial para entender a lógica da linguagem e não perder tempo com typos.

# %% [markdown]
# ### Lembrando: objetos
#
# Podemos atribuir a um objeto o resultado de nossas operações matemáticas ou, como veremos mais pra frente, o nosso dataframe. O objeto ficará armazenado na memória do jupyter e poderá ser acessado e modificado em operações futuras.
#
# Para atribuir uma operação a um objeto basta utilizar o sinal de =

# %%
# Exemplo:

obj = 2*4

# %% [markdown]
# *É possível traduzir esta operação com "obj RECEBE 2*4*

# %%
#Consultando:

obj

# %% [markdown]
# ## Bibliotecas:
#
# Bibliotecas são conjuntos de verbos que auxiliam a linguagem que estamos utilizando. São como "pacotes de expansão", permitindo que mais coisas sejam feitas dentro de uma determinada linguagem.
#
# Uma biblioteca muito utilizada na ciência de dados em python é a **Pandas** .
#
# Quando Python é instalado utilizando Anaconda, as bibliotecas *Pandas* e *NumPy* são instaladas automaticamente. Caso contrário, é possível instalar *Pandas* via pip no CMD com o comando `pip install pandas`.
#
# Depois de instalado, a biblioteca deve ser carregada no início de cada script:

# %%
#importando a biblioteca pandas e dando um "apelido" para ela.

import pandas as pd

#pd é a nomenclatura padrão.

# %% [markdown]
# Pronto, só isso =)
#
# As funções (verbos) costumam ser precedidos da biblioteca ou do objeto que ele irá trabalhar. Veremos exemplos a seguir.
#
# ## 01. Importando arquivos .CSV + Análise exploratória
#
#
# Vamos começar importando um banco de dados com todos os países do mundo e algumas informações básicas. Trata-se de um arquivo CSV, separado por ponto e vírgula e com encoding 'cp1252'

# %%
data_countries = pd.read_csv("data_countries.csv", encoding = 'cp1252', sep=";")

# %% [markdown]
# Em python é assim: se não aconteceu nada, é porque deu certo!
#
# Vamos primeiro olhar algumas características do banco, como número de linhas e colunas com o `shape`:

# %%
#Olhando qtde de linhas e colunas do meu df
data_countries.shape
# Out:
# (34, 2)

# %% [markdown]
# **Importante**: a contagem em Python começa no 0.
#
# Agora vamos olhar como são as cinco primeiras linhas deste dataframe com o comando `head()`:

# %%
#Verificando as cinco primeiras colunas
data_countries.head()
# Out:
#      country      continent
# 0  Argentina  South America
# 1  Argentina  South America
# 2  Argentina  South America
# 3  Australia        Oceania
# 4    Belgium         Europe

# %% [markdown]
# **Exercício rápido:** Este banco tem um problema, vocês conseguiram identificar?
# Vamos resolver esse problema daqui a pouco, na etapa de **02. Processamento**

# %% [markdown]
# E, por fim, vamos somar todos os *missing values* no nosso Dataframe:

# %%
# Contando a quantidade de missing values por coluna:
data_countries.isnull().sum()
# Out:
# country      0
# continent    0
# dtype: int64

# %% [markdown]
# Que bom, nosso banco não tem *missings*.
#
# Por fim, vamos ver os tipos de colunas existentes no nosso banco:

# %%
#Verificando os tipos de colunas:
data_countries.dtypes
# Out:
# country      object
# continent    object
# dtype: object

# %% [markdown]
# Agora vamos importar um segundo arquivo da FIFA com todos os jogadores convocados para a copa de 2018.
# É um arquivo .CSV , separado por ; e com encoding "UTF-8"

# %%
fifa = pd.read_csv("fifa2018.csv", sep=";")

# %% [markdown]
# Vamos executar as mesmas etapas que fizemos com o banco anterior:

# %%
#Primeiro, o shape:
fifa.shape
# Out:
# (736, 12)

# %%
#Agora, o head
fifa.head()
# Out:
#    number   fifa_display_name   last_name         first_name  shirt_name  \
# 0       1       Nahuel GUZMAN      GUZMÁN     Nahuel Ignacio      GUZMÁN
# 1       2     Gabriel MERCADO     MERCADO       Gabriel Ivan     MERCADO
# 2       3  Nicolas TAGLIAFICO  TAGLIAFICO  Nicolás Alejandro  TAGLIAFICO
# 3       4    Cristian ANSALDI     ANSALDI    Cristian Daniel     ANSALDI
# 4       5        Lucas BIGLIA      BIGLIA      Lucas Rodrigo      BIGLIA
#
#   day_of_birth position              club  height  caps  goals       team
# 0   10.02.1986       GK      Tigres (MEX)     192   6.0    NaN  Argentina
# 1   18.03.1987       DF  Sevilla FC (ESP)     181  21.0    3.0  Argentina
# 2   31.08.1992       DF        Ajax (NED)     169   6.0    NaN  Argentina
# 3   20.09.1986       DF      Torino (ITA)     181   5.0    1.0  Argentina
# 4   30.01.1986       MF    AC Milan (ITA)     175  58.0    1.0  Argentina

# %%
#Verificando soma dos missings dentro de nosso dataframe:
fifa.isnull().sum()
# Out:
# number                 0
# fifa_display_name      0
# last_name              0
# first_name             0
# shirt_name             0
# day_of_birth           0
# position               0
# club                   0
# height                 0
# caps                   4
# goals                290
# team                   0
# dtype: int64

# %%
#Verificando os tipos de colunas:
fifa.dtypes
# Out:
# number                 int64
# fifa_display_name     object
# last_name             object
# first_name            object
# shirt_name            object
# day_of_birth          object
# position              object
# club                  object
# height                 int64
# caps                 float64
# goals                float64
# team                  object
# dtype: object

# %% [markdown]
# *Float* e *Interger* são duas categorias numéricas em programação e variam quanto a sua precisão. Como vamos trabalhar com bancos simples, não existe diferença significativa na precisão dos números. Essas categorias são mais importantes para trabalhos científicos ou análises mais complexas.
#
# Saber os tipos de colunas é importante para evitar erros na importação de cadastros numéricos, como CPFs.

# %% [markdown]
# ### Consultas mais detalhadas:
#
# O dataframe Fifa contém informações sobre os jogadores convocados para copa do mundo de 2018.
#
# Vamos olhar uma descrição mais detalhada dos nossos dados:

# %%
#Breve descrição estatística:

fifa.describe()
# Out:
#           number      height        caps       goals
# count  736.00000  736.000000  732.000000  446.000000
# mean    12.00000  182.442935   36.505464    7.623318
# std      6.63776    6.858492   32.160911   10.412904
# min      1.00000  165.000000    1.000000    1.000000
# 25%      6.00000  178.000000   11.000000    2.000000
# 50%     12.00000  183.000000   27.000000    4.000000
# 75%     18.00000  187.000000   54.000000    9.000000
# max     23.00000  201.000000  158.000000   85.000000

# %% [markdown]
# Se eu quisesse apenas somar os valores de uma coluna, digamos, para saber quantos gols ao todo foram feitos por todos os jogadores até o momento da copa?

# %%
#somando itens de uma coluna:

fifa.goals.sum()
# Out:
# 3400.0

# %% [markdown]
# Agora eu gostaria de saber todas as seleções classificadas para a copa do mundo de 2018 (em outras palavras: todos os valores únicos da coluna "Team"):

# %%
#Acessando os valores únicos de uma variável:

pd.unique(fifa.team)
# Out:
# array(['Argentina', 'Australia', 'Belgium', 'Brazil', 'Colombia',
#        'Costa Rica', 'Croatia', 'Denmark', 'Egypt', 'England', 'France',
#        'Germany', 'Iceland', 'IR Iran', 'Japan', 'Korea Republic',
#        'Mexico', 'Morocco', 'Nigeria', 'Panama', 'Peru', 'Poland',
#        'Portugal', 'Russia', 'Saudi Arabia', 'Senegal', 'Serbia', 'Spain',
#        'Sweden', 'Switzerland', 'Tunisia', 'Uruguay'], dtype=object)

# %%
#E podemos atribuir esses valores a um objeto:

paises = pd.unique(fifa.team)
paises
# Out:
# array(['Argentina', 'Australia', 'Belgium', 'Brazil', 'Colombia',
#        'Costa Rica', 'Croatia', 'Denmark', 'Egypt', 'England', 'France',
#        'Germany', 'Iceland', 'IR Iran', 'Japan', 'Korea Republic',
#        'Mexico', 'Morocco', 'Nigeria', 'Panama', 'Peru', 'Poland',
#        'Portugal', 'Russia', 'Saudi Arabia', 'Senegal', 'Serbia', 'Spain',
#        'Sweden', 'Switzerland', 'Tunisia', 'Uruguay'], dtype=object)

# %% [markdown]
# E se eu quisesse que esse array virasse parte de um dataframe chamado `paises`, dentro de uma coluna chamada `pais` ?

# %%
paises = pd.DataFrame({'pais': pd.unique(fifa.team)})
paises.head()
# Out:
#         pais
# 0  Argentina
# 1  Australia
# 2    Belgium
# 3     Brazil
# 4   Colombia

# %% [markdown]
# Por fim, eu gostaria de fazer uma *query* e descobrir quais foram os jogadores da seleção brasileira na copa de 2018. Para isso, selecionarei as linhas cujo team == 'Brazil'

# %%
fifa.query('team == "Brazil"')
# Out:
#     number  fifa_display_name                   last_name        first_name  \
# 69       1            ALISSON                      BECKER    Alisson Ramses
# 70       2       THIAGO SILVA           EMILIANO DA SILVA            Thiago
# 71       3            MIRANDA      MIRANDA DE SOUZA FILHO              Joao
# 72       4      PEDRO GEROMEL               TONON GEROMEL             Pedro
# 73       5           CASEMIRO                    CASIMIRO   Carlos Henrique
# 74       6        FILIPE LUIS                   KASMIRSKI       Filipe Luis
# 75       7      DOUGLAS COSTA              COSTA DE SOUZA           Douglas
# 76       8     RENATO AUGUSTO  SOARES DE OLIVEIRA AUGUSTO            Renato
# 77       9      GABRIEL JESUS                    DE JESUS  Gabriel Fernando
# 78      10             NEYMAR      DA SILVA SANTOS JUNIOR            Neymar
# 79      11  PHILIPPE COUTINHO            COUTINHO CORREIA          Philippe
# 80      12            MARCELO      VIEIRA DA SILVA JUNIOR           Marcelo
# 81      13         MARQUINHOS                 AOAS CORREA            Marcos
# 82      14             DANILO                    DA SILVA       Danilo Luiz
# 83      15           PAULINHO       BEZERRA MACIEL JÚNIOR        José Paulo
# 84      16             CASSIO                       RAMOS            Cassio
# 85      17        FERNANDINHO                        ROZA     Fernando Luiz
# 86      18               FRED   RODRIGUES DE PAULA SANTOS         Frederico
# 87      19            WILLIAN             BORGES DA SILVA           Willian
# 88      20    ROBERTO FIRMINO         BARBOSA DE OLIVEIRA   Roberto Firmino
# 89      21             TAISON             BARCELLOS FREDA            Taison
# 90      22             FAGNER              CONSERVA LEMOS            Fagner
# 91      23            EDERSON           SANTANA DE MORAES           Ederson
#
#      shirt_name day_of_birth position                       club  height  \
# 69    A. BECKER   02.10.1992       GK              AS Roma (ITA)     193
# 70     T. SILVA   22.09.1984       DF  Paris Saint-Germain (FRA)     183
# 71      MIRANDA   07.09.1984       DF       Internazionale (ITA)     186
# 72      GEROMEL   21.09.1985       DF               Grêmio (BRA)     190
# 73     CASEMIRO   23.02.1992       MF          Real Madrid (ESP)     185
# 74  FILIPE LUIS   09.08.1985       DF      Atlético Madrid (ESP)     182
# 75     D. COSTA   14.09.1990       FW             Juventus (ITA)     182
# 76   R. AUGUSTO   08.02.1988       MF        Beijing Guoan (CHN)     186
# 77     G. JESUS   03.04.1997       FW      Manchester City (ENG)     175
# 78    NEYMAR JR   05.02.1992       FW  Paris Saint-Germain (FRA)     175
# 79  P. COUTINHO   12.06.1992       MF         FC Barcelona (ESP)     172
# 80      MARCELO   12.05.1988       DF          Real Madrid (ESP)     174
# 81   MARQUINHOS   14.05.1994       DF  Paris Saint-Germain (FRA)     183
# 82       DANILO   15.07.1991       DF      Manchester City (ENG)     184
# 83     PAULINHO   25.07.1988       MF         FC Barcelona (ESP)     181
# 84       CASSIO   06.06.1987       GK       SC Corinthians (BRA)     195
# 85  FERNANDINHO   04.05.1985       MF      Manchester City (ENG)     179
# 86         FRED   05.03.1993       MF     Shakhtar Donetsk (UKR)     169
# 87      WILLIAN   09.08.1988       MF              Chelsea (ENG)     175
# 88      FIRMINO   02.10.1991       FW            Liverpool (ENG)     181
# 89       TAISON   13.01.1988       FW     Shakhtar Donetsk (UKR)     172
# 90       FAGNER   11.06.1989       DF       SC Corinthians (BRA)     168
# 91      EDERSON   17.08.1993       GK      Manchester City (ENG)     188
#
#     caps  goals    team
# 69  28.0    NaN  Brazil
# 70  73.0    5.0  Brazil
# 71  49.0    2.0  Brazil
# 72   2.0    NaN  Brazil
# 73  26.0    NaN  Brazil
# 74  33.0    2.0  Brazil
# 75  26.0    3.0  Brazil
# 76  29.0    5.0  Brazil
# 77  19.0   10.0  Brazil
# 78  87.0   56.0  Brazil
# 79  38.0   12.0  Brazil
# 80  57.0    6.0  Brazil
# 81  26.0    NaN  Brazil
# 82  19.0    NaN  Brazil
# 83  52.0   12.0  Brazil
# 84   1.0    NaN  Brazil
# 85  46.0    2.0  Brazil
# 86   8.0    NaN  Brazil
# 87  59.0    8.0  Brazil
# 88  23.0    6.0  Brazil
# 89   8.0    1.0  Brazil
# 90   5.0    NaN  Brazil
# 91   1.0    NaN  Brazil

# %% [markdown]
# ## 02. Processamento de dados
#
# As vezes, precisamos não apenas consultar mas também modificar nossos dados para análise ou construção de um novo dataframe.

# %% [markdown]
# ### Removendo duplicatas:
#
# Vocês lembram do erro que nós vimos no banco `data_countries`? Agora vamos retirar as duplicatas:

# %%
#Removendo duplicatas:
data_countries = data_countries.drop_duplicates()

# %%
#Verificando a quantidade final de linhas:
data_countries.shape
# Out:
# (32, 2)

# %% [markdown]
# Se o dataframe não possui duplicatas, o `drop_duplicates()` não vai possuir efeito.
# Vamos usá-lo no banco FIFA:

# %%
#Removendo duplicatas
fifa = fifa.drop_duplicates()

#Verificando a quantidade final de linhas:
fifa.shape
# Out:
# (736, 12)

# %% [markdown]
# ### Substituindo os valores nulos de uma variável:
#
# Agora vamos substituir aqueles *missings* encontrados no banco fifa por zero com o `fillna()`:

# %%
#Sobrescrevendo NAs de uma coluna:
fifa.goals = fifa.goals.fillna(0)

#Consultando soma dos NAs
fifa.isnull().sum()
# Out:
# number               0
# fifa_display_name    0
# last_name            0
# first_name           0
# shirt_name           0
# day_of_birth         0
# position             0
# club                 0
# height               0
# caps                 4
# goals                0
# team                 0
# dtype: int64

# %% [markdown]
# **Exercício rápido:** Como sobrescrever os missings da variável *caps* ?

# %% [markdown]
# ### Criando novas variáveis
#
# Agora eu gostaria de criar uma nova variável no meu banco fifa, para afirmar que o esporte praticado por todos aqueles atletas é "futebol"

# %%
#Criando uma nova variável chamada esporte

fifa['esporte'] = "Futebol"

# %% [markdown]
# Ao atribuir o valor "Futebol" para o objeto `fifa['esporte']`, já estamos automaticamente criando a nova coluna no nosso dataframe.
#
# *OBS: A outra sintaxe `fifa.esporte` não funciona para criação de novas colunas

# %%
fifa.head()
# Out:
#    number   fifa_display_name   last_name         first_name  shirt_name  \
# 0       1       Nahuel GUZMAN      GUZMÁN     Nahuel Ignacio      GUZMÁN
# 1       2     Gabriel MERCADO     MERCADO       Gabriel Ivan     MERCADO
# 2       3  Nicolas TAGLIAFICO  TAGLIAFICO  Nicolás Alejandro  TAGLIAFICO
# 3       4    Cristian ANSALDI     ANSALDI    Cristian Daniel     ANSALDI
# 4       5        Lucas BIGLIA      BIGLIA      Lucas Rodrigo      BIGLIA
#
#   day_of_birth position              club  height  caps  goals       team  \
# 0   10.02.1986       GK      Tigres (MEX)     192   6.0    0.0  Argentina
# 1   18.03.1987       DF  Sevilla FC (ESP)     181  21.0    3.0  Argentina
# 2   31.08.1992       DF        Ajax (NED)     169   6.0    0.0  Argentina
# 3   20.09.1986       DF      Torino (ITA)     181   5.0    1.0  Argentina
# 4   30.01.1986       MF    AC Milan (ITA)     175  58.0    1.0  Argentina
#
#    esporte
# 0  Futebol
# 1  Futebol
# 2  Futebol
# 3  Futebol
# 4  Futebol

# %% [markdown]
# Agora, digamos que vocês estão elaborando as estatísticas dos jogadores antes da copa. Com essas informações da Fifa, seria interessante saber qual é a média de gols por jogador com a camisa da sua seleção. Para isso vamos criar uma nova coluna que divide o número de gols (goals) pelo número de jogos pela seleção (caps).

# %%
fifa['media_gols'] = fifa.goals/fifa.caps
fifa.head()
# Out:
#    number   fifa_display_name   last_name         first_name  shirt_name  \
# 0       1       Nahuel GUZMAN      GUZMÁN     Nahuel Ignacio      GUZMÁN
# 1       2     Gabriel MERCADO     MERCADO       Gabriel Ivan     MERCADO
# 2       3  Nicolas TAGLIAFICO  TAGLIAFICO  Nicolás Alejandro  TAGLIAFICO
# 3       4    Cristian ANSALDI     ANSALDI    Cristian Daniel     ANSALDI
# 4       5        Lucas BIGLIA      BIGLIA      Lucas Rodrigo      BIGLIA
#
#   day_of_birth position              club  height  caps  goals       team  \
# 0   10.02.1986       GK      Tigres (MEX)     192   6.0    0.0  Argentina
# 1   18.03.1987       DF  Sevilla FC (ESP)     181  21.0    3.0  Argentina
# 2   31.08.1992       DF        Ajax (NED)     169   6.0    0.0  Argentina
# 3   20.09.1986       DF      Torino (ITA)     181   5.0    1.0  Argentina
# 4   30.01.1986       MF    AC Milan (ITA)     175  58.0    1.0  Argentina
#
#    esporte  media_gols
# 0  Futebol    0.000000
# 1  Futebol    0.142857
# 2  Futebol    0.000000
# 3  Futebol    0.200000
# 4  Futebol    0.017241

# %% [markdown]
# E se quisessemos diminuir o número de casas decimais na nossa nova variável?

# %%
fifa['media_gols'] = round(fifa.goals/fifa.caps,2)
fifa.head()
# Out:
#    number   fifa_display_name   last_name         first_name  shirt_name  \
# 0       1       Nahuel GUZMAN      GUZMÁN     Nahuel Ignacio      GUZMÁN
# 1       2     Gabriel MERCADO     MERCADO       Gabriel Ivan     MERCADO
# 2       3  Nicolas TAGLIAFICO  TAGLIAFICO  Nicolás Alejandro  TAGLIAFICO
# 3       4    Cristian ANSALDI     ANSALDI    Cristian Daniel     ANSALDI
# 4       5        Lucas BIGLIA      BIGLIA      Lucas Rodrigo      BIGLIA
#
#   day_of_birth position              club  height  caps  goals       team  \
# 0   10.02.1986       GK      Tigres (MEX)     192   6.0    0.0  Argentina
# 1   18.03.1987       DF  Sevilla FC (ESP)     181  21.0    3.0  Argentina
# 2   31.08.1992       DF        Ajax (NED)     169   6.0    0.0  Argentina
# 3   20.09.1986       DF      Torino (ITA)     181   5.0    1.0  Argentina
# 4   30.01.1986       MF    AC Milan (ITA)     175  58.0    1.0  Argentina
#
#    esporte  media_gols
# 0  Futebol        0.00
# 1  Futebol        0.14
# 2  Futebol        0.00
# 3  Futebol        0.20
# 4  Futebol        0.02

# %% [markdown]
# ### Modificando datas
#
# Vocês devem ter reparado quando usamos a função `fifa.dtypes` que a coluna *day_of_birt* está como *object*, neste caso texto. Vamos sobrescrever essa coluna com os mesmos valores, mas como Data. Para isso usamos a função do pandas `pd.to_datetime`.

# %%
#Sobrescrevendo variável categórica como data:

fifa['day_of_birth'] = pd.to_datetime(fifa['day_of_birth']) 

#Consultando:
fifa.head()
# Out:
#    number   fifa_display_name   last_name         first_name  shirt_name  \
# 0       1       Nahuel GUZMAN      GUZMÁN     Nahuel Ignacio      GUZMÁN
# 1       2     Gabriel MERCADO     MERCADO       Gabriel Ivan     MERCADO
# 2       3  Nicolas TAGLIAFICO  TAGLIAFICO  Nicolás Alejandro  TAGLIAFICO
# 3       4    Cristian ANSALDI     ANSALDI    Cristian Daniel     ANSALDI
# 4       5        Lucas BIGLIA      BIGLIA      Lucas Rodrigo      BIGLIA
#
#   day_of_birth position              club  height  caps  goals       team  \
# 0   1986-10-02       GK      Tigres (MEX)     192   6.0    0.0  Argentina
# 1   1987-03-18       DF  Sevilla FC (ESP)     181  21.0    3.0  Argentina
# 2   1992-08-31       DF        Ajax (NED)     169   6.0    0.0  Argentina
# 3   1986-09-20       DF      Torino (ITA)     181   5.0    1.0  Argentina
# 4   1986-01-30       MF    AC Milan (ITA)     175  58.0    1.0  Argentina
#
#    esporte  media_gols
# 0  Futebol        0.00
# 1  Futebol        0.14
# 2  Futebol        0.00
# 3  Futebol        0.20
# 4  Futebol        0.02

# %% [markdown]
# ### Renomeando variáveis
#
# Caps é um nome muito ruim. Vamos colocar um nome mais intuitívo, como *jogos_selecao*

# %%
#Renomeando e atribuindo ao nosso dataframe:
fifa = fifa.rename(columns={"caps": "jogos_selecao"})

#Consultando
fifa.head()
# Out:
#    number   fifa_display_name   last_name         first_name  shirt_name  \
# 0       1       Nahuel GUZMAN      GUZMÁN     Nahuel Ignacio      GUZMÁN
# 1       2     Gabriel MERCADO     MERCADO       Gabriel Ivan     MERCADO
# 2       3  Nicolas TAGLIAFICO  TAGLIAFICO  Nicolás Alejandro  TAGLIAFICO
# 3       4    Cristian ANSALDI     ANSALDI    Cristian Daniel     ANSALDI
# 4       5        Lucas BIGLIA      BIGLIA      Lucas Rodrigo      BIGLIA
#
#   day_of_birth position              club  height  jogos_selecao  goals  \
# 0   1986-10-02       GK      Tigres (MEX)     192            6.0    0.0
# 1   1987-03-18       DF  Sevilla FC (ESP)     181           21.0    3.0
# 2   1992-08-31       DF        Ajax (NED)     169            6.0    0.0
# 3   1986-09-20       DF      Torino (ITA)     181            5.0    1.0
# 4   1986-01-30       MF    AC Milan (ITA)     175           58.0    1.0
#
#         team  esporte  media_gols
# 0  Argentina  Futebol        0.00
# 1  Argentina  Futebol        0.14
# 2  Argentina  Futebol        0.00
# 3  Argentina  Futebol        0.20
# 4  Argentina  Futebol        0.02

# %% [markdown]
# E se eu quisesse agora renomear várias colunas ao mesmo tempo?

# %%
#Renomeando
fifa = fifa.rename(columns={"number": "num_camisa",
                            "fifa_display_name": "nome_fifa"})
fifa.head()
# Out:
#    num_camisa           nome_fifa   last_name         first_name  shirt_name  \
# 0           1       Nahuel GUZMAN      GUZMÁN     Nahuel Ignacio      GUZMÁN
# 1           2     Gabriel MERCADO     MERCADO       Gabriel Ivan     MERCADO
# 2           3  Nicolas TAGLIAFICO  TAGLIAFICO  Nicolás Alejandro  TAGLIAFICO
# 3           4    Cristian ANSALDI     ANSALDI    Cristian Daniel     ANSALDI
# 4           5        Lucas BIGLIA      BIGLIA      Lucas Rodrigo      BIGLIA
#
#   day_of_birth position              club  height  jogos_selecao  goals  \
# 0   1986-10-02       GK      Tigres (MEX)     192            6.0    0.0
# 1   1987-03-18       DF  Sevilla FC (ESP)     181           21.0    3.0
# 2   1992-08-31       DF        Ajax (NED)     169            6.0    0.0
# 3   1986-09-20       DF      Torino (ITA)     181            5.0    1.0
# 4   1986-01-30       MF    AC Milan (ITA)     175           58.0    1.0
#
#         team  esporte  media_gols
# 0  Argentina  Futebol        0.00
# 1  Argentina  Futebol        0.14
# 2  Argentina  Futebol        0.00
# 3  Argentina  Futebol        0.20
# 4  Argentina  Futebol        0.02

# %% [markdown]
# ## 03. Juntando dois dataframes
#
# Uma das belezas de trabalhar com dados em Python é que podemos juntar dois dataframes diferentes por meio de uma *chave* comum ou "colar" dois dataframes iguais um sobre o outro.
#
# ### Merge
#
# Com a função `merge` é possível juntar dois dataframes horizontalmente baseados em uma coluna (key) comum. Ele opera de maneira similar ao SQL::JOIN e ao DPLYR::left_join
#
#
# Vamos criar um terceiro dataframe chamado fifa_countries, que irá conter a junção dos bancos fifa e data_countries:

# %%
#Joining

fifa_countries = pd.merge(fifa, data_countries, left_on=['team'], right_on=['country'])

fifa_countries.head()
# Out:
#    num_camisa           nome_fifa   last_name         first_name  shirt_name  \
# 0           1       Nahuel GUZMAN      GUZMÁN     Nahuel Ignacio      GUZMÁN
# 1           2     Gabriel MERCADO     MERCADO       Gabriel Ivan     MERCADO
# 2           3  Nicolas TAGLIAFICO  TAGLIAFICO  Nicolás Alejandro  TAGLIAFICO
# 3           4    Cristian ANSALDI     ANSALDI    Cristian Daniel     ANSALDI
# 4           5        Lucas BIGLIA      BIGLIA      Lucas Rodrigo      BIGLIA
#
#   day_of_birth position              club  height  jogos_selecao  goals  \
# 0   1986-10-02       GK      Tigres (MEX)     192            6.0    0.0
# 1   1987-03-18       DF  Sevilla FC (ESP)     181           21.0    3.0
# 2   1992-08-31       DF        Ajax (NED)     169            6.0    0.0
# 3   1986-09-20       DF      Torino (ITA)     181            5.0    1.0
# 4   1986-01-30       MF    AC Milan (ITA)     175           58.0    1.0
#
#         team  esporte  media_gols    country      continent
# 0  Argentina  Futebol        0.00  Argentina  South America
# 1  Argentina  Futebol        0.14  Argentina  South America
# 2  Argentina  Futebol        0.00  Argentina  South America
# 3  Argentina  Futebol        0.20  Argentina  South America
# 4  Argentina  Futebol        0.02  Argentina  South America

# %% [markdown]
# Tivemos que usar os parâmetros `left_on` e `right_on` porque as colunas-chave possuem nomes diferentes nos dois bancos. A outra opção é renomear a coluna de um dos dois bancos para precisarmos apenas especificar o parâmetro `on`, como faremos a seguir:

# %%
#Renomeando:
fifa = fifa.rename(columns={'team': 'country'})

#Juntando:
fifa_countries = pd.merge(fifa, data_countries, on='country')

fifa_countries.head()
# Out:
#    num_camisa           nome_fifa   last_name         first_name  shirt_name  \
# 0           1       Nahuel GUZMAN      GUZMÁN     Nahuel Ignacio      GUZMÁN
# 1           2     Gabriel MERCADO     MERCADO       Gabriel Ivan     MERCADO
# 2           3  Nicolas TAGLIAFICO  TAGLIAFICO  Nicolás Alejandro  TAGLIAFICO
# 3           4    Cristian ANSALDI     ANSALDI    Cristian Daniel     ANSALDI
# 4           5        Lucas BIGLIA      BIGLIA      Lucas Rodrigo      BIGLIA
#
#   day_of_birth position              club  height  jogos_selecao  goals  \
# 0   1986-10-02       GK      Tigres (MEX)     192            6.0    0.0
# 1   1987-03-18       DF  Sevilla FC (ESP)     181           21.0    3.0
# 2   1992-08-31       DF        Ajax (NED)     169            6.0    0.0
# 3   1986-09-20       DF      Torino (ITA)     181            5.0    1.0
# 4   1986-01-30       MF    AC Milan (ITA)     175           58.0    1.0
#
#      country  esporte  media_gols      continent
# 0  Argentina  Futebol        0.00  South America
# 1  Argentina  Futebol        0.14  South America
# 2  Argentina  Futebol        0.00  South America
# 3  Argentina  Futebol        0.20  South America
# 4  Argentina  Futebol        0.02  South America

# %% [markdown]
# ### Concat
#
# Para "empilhar" dois dataframes, vamos usar a função `concat`.
# Vamos criar um dataframe com apenas uma observação (linha), que seria um novo jogador inventado para a seleção da Argentina. Esse novo dataframe terá as mesmas colunas do dataframe fifa:

# %%
extra = pd.DataFrame({'num_camisa': [100]                      ,
                      'nome_fifa': ['DALÍ'],
                      'last_name': ['Dalí'],
                      'first_name': ['Salvador'],
                      'shirt_name': ['DALÍ'],
                      'day_of_birth': ['2013-10-10'],
                      'position': ['GK'],
                      'club': ['Barcelona(ESP)'],
                      'height': [100],
                      'jogos_selecao': [0],
                      'goals': [0],
                      'country': ['Argentina'],
                      'esporte': ['Futebol'],
                      'media_gols': [0],
                      'continent': ['South America']})

extra
# Out:
#    num_camisa nome_fifa last_name first_name shirt_name day_of_birth position  \
# 0         100      DALÍ      Dalí   Salvador       DALÍ   2013-10-10       GK
#
#              club  height  jogos_selecao  goals    country  esporte  \
# 0  Barcelona(ESP)     100              0      0  Argentina  Futebol
#
#    media_gols      continent
# 0           0  South America

# %%
#Concatenando dois dataframes:

fifa_extra = pd.concat([fifa , extra], axis = 0, sort=False)

# %% [markdown]
# O parâmetro `axis = 0` indica que os dataframes serão agrupados verticalmente, e o parâmetro `sort = FALSE` estabelece que não haverá alteração na disposição das colunas

# %%
#Procurando os jogadores do time da Argentina:

fifa_extra.query('country == "Argentina"')
# Out:
#     num_camisa           nome_fifa   last_name               first_name  \
# 0            1       Nahuel GUZMAN      GUZMÁN           Nahuel Ignacio
# 1            2     Gabriel MERCADO     MERCADO             Gabriel Ivan
# 2            3  Nicolas TAGLIAFICO  TAGLIAFICO        Nicolás Alejandro
# 3            4    Cristian ANSALDI     ANSALDI          Cristian Daniel
# 4            5        Lucas BIGLIA      BIGLIA            Lucas Rodrigo
# 5            6      Federico FAZIO       FAZIO          Federico Julián
# 6            7         Ever BANEGA      BANEGA   Ever Maximiliano David
# 7            8        Marcos ACUNA       ACUÑA            Marcos Javier
# 8            9     Gonzalo HIGUAIN     HIGUAIN          Gonzalo Gerardo
# 9           10        Lionel MESSI       MESSI            Lionel Andres
# 10          11      Angel DI MARIA    DI MARIA             Angel Fabian
# 11          12       Franco ARMANI      ARMANI                   Franco
# 12          13    Maximiliano MEZA        MEZA      Maximiliano Eduardo
# 13          14   Javier MASCHERANO  MASCHERANO         Javier Alejandro
# 14          15          Enzo PEREZ       PEREZ             Enzo Nicolas
# 15          16         Marcos ROJO        ROJO  Faustino Marcos Alberto
# 16          17    Nicolas OTAMENDI    OTAMENDI   Nicolas Hernan Gonzalo
# 17          18      Eduardo SALVIO      SALVIO          Eduardo Antonio
# 18          19       Sergio AGUERO      AGÜERO            Sergio Leonel
# 19          20    Giovani LO CELSO    LO CELSO                  Giovani
# 20          21        Paulo DYBALA      DYBALA           Paulo Exequiel
# 21          22      Cristian PAVON       PAVÓN           Cristian David
# 22          23  Wilfredo CABALLERO   CABALLERO          Wilfredo Daniel
# 0          100                DALÍ        Dalí                 Salvador
#
#      shirt_name         day_of_birth position                       club  \
# 0        GUZMÁN  1986-10-02 00:00:00       GK               Tigres (MEX)
# 1       MERCADO  1987-03-18 00:00:00       DF           Sevilla FC (ESP)
# 2    TAGLIAFICO  1992-08-31 00:00:00       DF                 Ajax (NED)
# 3       ANSALDI  1986-09-20 00:00:00       DF               Torino (ITA)
# 4        BIGLIA  1986-01-30 00:00:00       MF             AC Milan (ITA)
# 5         FAZIO  1987-03-17 00:00:00       DF              AS Roma (ITA)
# 6        BANEGA  1988-06-29 00:00:00       MF           Sevilla FC (ESP)
# 7         ACUÑA  1991-10-28 00:00:00       DF          Sporting CP (POR)
# 8       HIGUAÍN  1987-10-12 00:00:00       FW             Juventus (ITA)
# 9         MESSI  1987-06-24 00:00:00       FW         FC Barcelona (ESP)
# 10     DI MARÍA  1988-02-14 00:00:00       MF  Paris Saint-Germain (FRA)
# 11       ARMANI  1986-10-16 00:00:00       GK          River Plate (ARG)
# 12         MEZA  1992-12-15 00:00:00       MF        Independiente (ARG)
# 13   MASCHERANO  1984-08-06 00:00:00       DF         Hebei Huabei (CHN)
# 14        PÉREZ  1986-02-22 00:00:00       MF          River Plate (ARG)
# 15  MARCOS ROJO  1990-03-20 00:00:00       DF    Manchester United (ENG)
# 16     OTAMENDI  1988-12-02 00:00:00       DF      Manchester City (ENG)
# 17       SALVIO  1990-07-13 00:00:00       DF              Benfica (POR)
# 18   KUN AGUERO  1988-02-06 00:00:00       FW      Manchester City (ENG)
# 19     LO CELSO  1996-09-04 00:00:00       MF  Paris Saint-Germain (FRA)
# 20       DYBALA  1993-11-15 00:00:00       FW             Juventus (ITA)
# 21        PAVÓN  1996-01-21 00:00:00       MF         Boca Juniors (ARG)
# 22    CABALLERO  1981-09-28 00:00:00       GK              Chelsea (ENG)
# 0          DALÍ           2013-10-10       GK             Barcelona(ESP)
#
#     height  jogos_selecao  goals    country  esporte  media_gols  \
# 0      192            6.0    0.0  Argentina  Futebol        0.00
# 1      181           21.0    3.0  Argentina  Futebol        0.14
# 2      169            6.0    0.0  Argentina  Futebol        0.00
# 3      181            5.0    1.0  Argentina  Futebol        0.20
# 4      175           58.0    1.0  Argentina  Futebol        0.02
# 5      199            9.0    1.0  Argentina  Futebol        0.11
# 6      175           63.0    6.0  Argentina  Futebol        0.10
# 7      172           11.0    0.0  Argentina  Futebol        0.00
# 8      184           74.0   31.0  Argentina  Futebol        0.42
# 9      170          126.0   64.0  Argentina  Futebol        0.51
# 10     178           95.0   19.0  Argentina  Futebol        0.20
# 11     189            NaN    0.0  Argentina  Futebol         NaN
# 12     180            4.0    0.0  Argentina  Futebol        0.00
# 13     174          145.0    3.0  Argentina  Futebol        0.02
# 14     178           24.0    1.0  Argentina  Futebol        0.04
# 15     189           57.0    2.0  Argentina  Futebol        0.04
# 16     181           56.0    4.0  Argentina  Futebol        0.07
# 17     167           11.0    0.0  Argentina  Futebol        0.00
# 18     172           87.0   38.0  Argentina  Futebol        0.44
# 19     177            5.0    0.0  Argentina  Futebol        0.00
# 20     177           13.0    0.0  Argentina  Futebol        0.00
# 21     169            7.0    0.0  Argentina  Futebol        0.00
# 22     186            5.0    0.0  Argentina  Futebol        0.00
# 0      100            0.0    0.0  Argentina  Futebol        0.00
#
#         continent
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# 9             NaN
# 10            NaN
# 11            NaN
# 12            NaN
# 13            NaN
# 14            NaN
# 15            NaN
# 16            NaN
# 17            NaN
# 18            NaN
# 19            NaN
# 20            NaN
# 21            NaN
# 22            NaN
# 0   South America

# %% [markdown]
# Nosso novo jogador está aí ;)

# %% [markdown]
# ## 03. Realizando operações com agrupamentos
#
# Agora que nós já aprendemos analisar, processar e fundir diferentes bancos de dados restam apenas as operações seguidas de  agrupamentos.
#
# Vamos primeiro criar uma nova coluna *boolean* (true e false), que me dirá se determinado jogador tem mais de 1,80m:

# %%
#Criando nossa coluna boolean:
fifa_countries['alto'] = fifa_countries.height > 180

#Verificando:
fifa_countries.head()
# Out:
#    num_camisa           nome_fifa   last_name         first_name  shirt_name  \
# 0           1       Nahuel GUZMAN      GUZMÁN     Nahuel Ignacio      GUZMÁN
# 1           2     Gabriel MERCADO     MERCADO       Gabriel Ivan     MERCADO
# 2           3  Nicolas TAGLIAFICO  TAGLIAFICO  Nicolás Alejandro  TAGLIAFICO
# 3           4    Cristian ANSALDI     ANSALDI    Cristian Daniel     ANSALDI
# 4           5        Lucas BIGLIA      BIGLIA      Lucas Rodrigo      BIGLIA
#
#   day_of_birth position              club  height  jogos_selecao  goals  \
# 0   1986-10-02       GK      Tigres (MEX)     192            6.0    0.0
# 1   1987-03-18       DF  Sevilla FC (ESP)     181           21.0    3.0
# 2   1992-08-31       DF        Ajax (NED)     169            6.0    0.0
# 3   1986-09-20       DF      Torino (ITA)     181            5.0    1.0
# 4   1986-01-30       MF    AC Milan (ITA)     175           58.0    1.0
#
#      country  esporte  media_gols      continent   alto
# 0  Argentina  Futebol        0.00  South America   True
# 1  Argentina  Futebol        0.14  South America   True
# 2  Argentina  Futebol        0.00  South America  False
# 3  Argentina  Futebol        0.20  South America   True
# 4  Argentina  Futebol        0.02  South America  False

# %% [markdown]
# Agora vamos verificar qual é a média de gols para jogadores maiores e menores que 180. Para isso, vamos usar o `groupby`e depois `sum`:

# %%
fifa_countries.groupby('alto')['goals'].median()
# Out:
# alto
# False    2.0
# True     1.0
# Name: goals, dtype: float64

# %% [markdown]
# Agora eu vou agrupar por *continent* e *alto*:

# %%
fifa_countries.groupby(['continent','alto'])['goals'].median()
# Out:
# continent        alto
# Africa           False    1.0
#                  True     1.0
# Asia             False    1.0
#                  True     1.0
# Central America  False    0.0
#                  True     2.0
# Europe           False    2.0
#                  True     1.0
# North America    False    7.5
#                  True     1.0
# Oceania          False    2.0
#                  True     1.5
# South America    False    1.0
#                  True     1.0
# Name: goals, dtype: float64

# %% [markdown]
# Agora além de agrupar por *continent* e *alto* eu vou verificar a média de gols e o total de gols feitos. Para isso vamos usar o `agg`:

# %%
fifa_countries.groupby(['continent','alto']).agg({'goals': ['median', 'sum']})
# Out:
#                        goals         club
#                       median    sum count
# continent       alto
# Africa          False    1.0  171.0    41
#                 True     1.0  148.0    74
# Asia            False    1.0  219.0    46
#                 True     1.0  222.0    46
# Central America False    0.0   57.0    20
#                 True     2.0  198.0    26
# Europe          False    2.0  431.0    93
#                 True     1.0  994.0   229
# North America   False    7.5  172.0    14
#                 True     1.0   34.0     9
# Oceania         False    2.0   77.0    13
#                 True     1.5   46.0    10
# South America   False    1.0  363.0    59
#                 True     1.0  268.0    56

# %% [markdown]
# Agora em um nível mais hard eu quero saber, além da média e do total de gols, quantos jogadores acima e abaixo de 1,80m eu tenho em cada continente:

# %%
fifa_countries.groupby(['continent','alto']).agg({'alto':['count'],
                                                  'goals': ['median', 'sum']})
# Out:
#                        alto  goals
#                       count median    sum
# continent       alto
# Africa          False    41    1.0  171.0
#                 True     74    1.0  148.0
# Asia            False    46    1.0  219.0
#                 True     46    1.0  222.0
# Central America False    20    0.0   57.0
#                 True     26    2.0  198.0
# Europe          False    93    2.0  431.0
#                 True    229    1.0  994.0
# North America   False    14    7.5  172.0
#                 True      9    1.0   34.0
# Oceania         False    13    2.0   77.0
#                 True     10    1.5   46.0
# South America   False    59    1.0  363.0
#                 True     56    1.0  268.0
